# %%
#Create a dataframe using dictionary of dictionary (nested dictionary)
import pandas as pd
dict2={
    'Manager':{'IT Support':'Shawn','Operations':'Jacob','System Infrastructure':'Harvey','Info Security':'Joey'},
    'Engineer':{'IT Support':'Sahil','Operations':'Daniel','System Infrastructure':'Monika','Info Security':'Rachel'},
    }
df6=pd.DataFrame(dict2)
df6
# Out:
#                       Manager Engineer
# IT Support              Shawn    Sahil
# Operations              Jacob   Daniel
# System Infrastructure  Harvey   Monika
# Info Security            Joey   Rachel

# %%
#Create dataframe using Numpy Array
import numpy as np
dict2={
    'Manager':{'IT Support':'Shawn','Operations':'Jacob','System Infrastructure':'Harvey','Info Security':'Joey'},
    'Engineer':{'IT Support':'Sahil','Operations':'Daniel','System Infrastructure':'Monika','Info Security':'Rachel'},
    }
arr=np.array([dict2])
data=pd.DataFrame(arr[0])
data
# Out:
#                       Manager Engineer
# IT Support              Shawn    Sahil
# Operations              Jacob   Daniel
# System Infrastructure  Harvey   Monika
# Info Security            Joey   Rachel

# %%
#DataFrame to CSV with index
df6.to_csv('california_housing_test.csv')
df6
# Out:
#                       Manager Engineer
# IT Support              Shawn    Sahil
# Operations              Jacob   Daniel
# System Infrastructure  Harvey   Monika
# Info Security            Joey   Rachel

# %%
#DataFrame without index
df6.to_csv('California_housing_test_withput_index.csv',index=False)

# %%
s3=pd.Series(['kabaddi','kho-kho','volley ball'])
s4=pd.Series([7,12,5])

dict={'sports':s3,'No of Players:':s4}
df5=pd.DataFrame(dict)
df5
# Out:
#         sports  No of Players:
# 0      kabaddi               7
# 1      kho-kho              12
# 2  volley ball               5

# %%
df5.to_csv('Player.csv')
df5
# Out:
#         sports  No of Players:
# 0      kabaddi               7
# 1      kho-kho              12
# 2  volley ball               5

# %%
df5.to_csv('Player_without_index.csv',index=False)

# %%
#IF dataframe is large
#tail() = returns a specified number of last rows
df6.tail(2)
# Out:
#                       Manager Engineer
# System Infrastructure  Harvey   Monika
# Info Security            Joey   Rachel

# %%
#head() - returns a specified number of rows, from the top
df6.head(2)
# Out:
#            Manager Engineer
# IT Support   Shawn    Sahil
# Operations   Jacob   Daniel

# %%
#Data Pre-processing
df = pd.read_csv('/content/Temp.csv')
df
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2021         32.0        6.0    Rain
# 1  01-04-2021          NaN        9.0   Sunny
# 2  01-05-2021         28.0        NaN    Snow
# 3  01-06-2021          NaN        7.0     NaN
# 4  01-07-2021         32.0        NaN     NaN
# 5  01-08-2021          NaN        NaN   Sunny
# 6  01-09-2021          NaN        NaN     NaN
# 7  01-10-2021         34.0        8.0  Cloudy
# 8  01-11-2021         40.0       12.0   Sunny

# %%
#Replacing Nan with 0
df.fillna(0)
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2021         32.0        6.0    Rain
# 1  01-04-2021          0.0        9.0   Sunny
# 2  01-05-2021         28.0        0.0    Snow
# 3  01-06-2021          0.0        7.0       0
# 4  01-07-2021         32.0        0.0       0
# 5  01-08-2021          0.0        0.0   Sunny
# 6  01-09-2021          0.0        0.0       0
# 7  01-10-2021         34.0        8.0  Cloudy
# 8  01-11-2021         40.0       12.0   Sunny

# %%
#Specifying No event values in event columns instead of 0
newdf=df.fillna({
    'temperature':0,
    'windspeed':0,
    'event':'No event'
})
df
# Out:
#           day  temperature  windspeed     event
# 0  01-01-2021         32.0        6.0      Rain
# 1  01-04-2021          0.0        9.0     Sunny
# 2  01-05-2021         28.0        0.0      Snow
# 3  01-06-2021          0.0        7.0  No event
# 4  01-07-2021         32.0        0.0  No event
# 5  01-08-2021          0.0        0.0     Sunny
# 6  01-09-2021          0.0        0.0  No event
# 7  01-10-2021         34.0        8.0    Cloudy
# 8  01-11-2021         40.0       12.0     Sunny

# %%
newdf=df.fillna(method="ffill")
newdf
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2021         32.0        6.0    Rain
# 1  01-04-2021         32.0        9.0   Sunny
# 2  01-05-2021         28.0        9.0    Snow
# 3  01-06-2021         28.0        7.0    Snow
# 4  01-07-2021         32.0        7.0    Snow
# 5  01-08-2021         32.0        7.0   Sunny
# 6  01-09-2021         32.0        7.0   Sunny
# 7  01-10-2021         34.0        8.0  Cloudy
# 8  01-11-2021         40.0       12.0   Sunny

# %%
newdf=df.fillna(method="bfill")
newdf
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2021         32.0        6.0    Rain
# 1  01-04-2021         28.0        9.0   Sunny
# 2  01-05-2021         28.0        7.0    Snow
# 3  01-06-2021         32.0        7.0   Sunny
# 4  01-07-2021         32.0        8.0   Sunny
# 5  01-08-2021         34.0        8.0   Sunny
# 6  01-09-2021         34.0        8.0  Cloudy
# 7  01-10-2021         34.0        8.0  Cloudy
# 8  01-11-2021         40.0       12.0   Sunny

# %%
#Temp on 1st Jan is 32, on 5th Jan is 28
#For getting temp in-between 32 & 28 on 4th Jan
newdf3=df.interpolate()
newdf3
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2021    32.000000       6.00    Rain
# 1  01-04-2021    30.000000       9.00   Sunny
# 2  01-05-2021    28.000000       8.00    Snow
# 3  01-06-2021    30.000000       7.00     NaN
# 4  01-07-2021    32.000000       7.25     NaN
# 5  01-08-2021    32.666667       7.50   Sunny
# 6  01-09-2021    33.333333       7.75     NaN
# 7  01-10-2021    34.000000       8.00  Cloudy
# 8  01-11-2021    40.000000      12.00   Sunny

# %%
#Drop Nan values with dropna()
newdf4=df.dropna()
newdf4
# Out:
#           day  temperature  windspeed   event
# 0  01-01-2021         32.0        6.0    Rain
# 7  01-10-2021         34.0        8.0  Cloudy
# 8  01-11-2021         40.0       12.0   Sunny
